# %%
import csv
data = [["Name", "Age","Location"],["John",25,"Usa"],["Rin",19,"Usa"]]

with open ("csv_read_write.csv","w",newline="",)as file:
  csv_writer =csv.writer(file)
  csv_writer.writerows(data)

print("Data Added Sucessfully")
# Out:
# Data Added Sucessfully

# %%
# !cat csv_read_write.csv
# Out:
# Name,Age,Location
# John,25,Usa
# Rin,19,Usa

# %% [markdown]
# ## Read The File

# %%
import csv
with open("csv_read_write.csv","r",newline="") as file:
  csv_reader =csv.reader(file)
  for i in csv_reader:
    print(i)
# Out:
# ['Name', 'Age', 'Location']
# ['John', '25', 'Usa']
# ['Rin', '19', 'Usa']
# ['John', '15', 'USA']

# %% [markdown]
# ##Lets make it dynamic

# %%
def adding_data_csv(Name,Age,Location):
  import csv
  with open("csv_read_write.csv","a",newline="") as file:
    csv_writer = csv.writer(file)
    csv_writer.writerow([Name,Age,Location])

Name =input("Enter The Name:")
Age =int(input("Enter The Age :"))
Location =input("Enter The Place Name:")

adding_data_csv(Name,Age,Location)
# Out:
# Enter The Name:John
# Enter The Age :15
# Enter The Place Name:USA

# %% [markdown]
# ## Working With Dictionary File In Csv

# %%
import csv
def create_csv_dict(name ,work,domain):
  keys_data= ["name","work","domain"]
  data =[{"name":name,"work":work,"domain":domain}]
  with open ("employee_data.csv","w",newline="")as file:
    csv_dict_writer=csv.DictWriter(file,fieldnames=keys_data)
    csv_dict_writer.writeheader()
    csv_dict_writer.writerows(data)
name =input("Enter The Name :")
work =input("Enter the Work What you Do?:")
domain=input("Enter Which Domain You work:")

create_csv_dict(name,work,domain)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-4261d8b949ad> in <cell line: 9>()
#       7     csv_dict_writer.writeheader()
#       8     csv_dict_writer.writerows(data)
# ----> 9 name =input("Enter The Name :")
#      10 work =input("Enter the Work What you Do?:")
#      11 domain=input("Enter Which Domain You work:")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %%
# !ls
# Out:
# csv_read_write.csv  employee_data.csv  sample_data

# %%
# !cat employee_data.csv
# Out:
# name,work,domain
# Thomas Shelby,Bad Boy,gangstar

# %% [markdown]
# ## static dict reader

# %%
import csv
with open ("employee_data.csv","r",newline="") as file :
  csv_dict_reader =csv.DictReader(file)
  for i in csv_dict_reader:
    print(i)
# Out:
# {'name': 'Hinata', 'work': 'Actress', 'domain': 'Anime'}
# {'name': 'name', 'work': 'work', 'domain': 'domain'}
# {'name': 'Hinata', 'work': 'Actress', 'domain': 'Anime'}
