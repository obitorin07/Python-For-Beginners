# %% [markdown]
# #Data Analysis: Introduction to Pandas

# %% [markdown]
# ### Method 1: Load a CSV file and display basic information

# %%
#import library/module
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv('/content/salary_data.csv')

# %%
# Display the first few rows of the dataset
df.head()
# Out:
#                    Position State Sex MaritalDesc CitizenDesc  \
# 0              Accountant I   NaN   F     Married  US Citizen
# 1              Accountant I    MA  M     Divorced  US Citizen
# 2              Accountant I    MA  M       Single         NaN
# 3  Administrative Assistant    MA   F         NaN  US Citizen
# 4                       NaN    MA   F      Single  US Citizen
#
#        EmploymentStatus     Department  Salaries   age  \
# 0                Active  Admin Offices    674.28   NaN
# 1                Active  Admin Offices    674.28  50.0
# 2                Active  Admin Offices    674.28  43.0
# 3  Terminated for Cause  Admin Offices  47822.00  44.0
# 4                Active  Admin Offices       NaN  33.0
#
#                         Race
# 0  Black or African American
# 1  Black or African American
# 2                      White
# 3                        NaN
# 4                      White

# %%
# Display the last few rows of the dataset
df.tail()
# Out:
#                  Position State Sex MaritalDesc CitizenDesc  EmploymentStatus  \
# 305  Sr. Network Engineer    CT   F     Married  US Citizen  Leave of Absence
# 306  Sr. Network Engineer    MA  M      Married  US Citizen  Leave of Absence
# 307                   NaN    MA  M      Married  US Citizen      Future Start
# 308  Sr. Network Engineer    CT  M          NaN  US Citizen            Active
# 309  Sr. Network Engineer    MA   F     Widowed  US Citizen            Active
#
#     Department  Salaries   age   Race
# 305      IT/IS       NaN  38.0  White
# 306      IT/IS  27603.00  34.0  White
# 307      IT/IS  27587.46  24.0  Asian
# 308      IT/IS  12126.53  31.0  White
# 309      IT/IS  37257.00  46.0  Asian

# %%
# Display basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Position          267 non-null    object
#  1   State             275 non-null    object
#  2   Sex               276 non-null    object
#  3   MaritalDesc       281 non-null    object
#  4   CitizenDesc       283 non-null    object
#  5   EmploymentStatus  278 non-null    object
#  6   Department        292 non-null    object
#  7   Salaries          278 non-null    float64
#  8   age               275 non-null    float64
#  9   Race              285 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 24.3+ KB

# %% [markdown]
# ###Method 2: Calculate basic statistics

# %%
# Calculate summary statistics
df.describe()
# Out:
#             Salaries         age
# count     278.000000  275.000000
# mean    36725.396007   38.592727
# std     20997.074151    9.290994
# min        75.000000   23.000000
# 25%     24294.772500   30.500000
# 50%     35568.315000   39.000000
# 75%     51452.895000   46.000000
# max    108304.000000   54.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Salaries'].plot(kind='hist', bins=20, title='Salaries')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %% [markdown]
# ###Method 3: Data manipulation and filtering

# %%
# Select specific columns

df.head()

specific_col = df[['Position', "State", "Sex", "Department", "Salaries"]]
specific_col.head(10)
# Out:
#                    Position State  Sex     Department  Salaries
# 0              Accountant I   NaN    F  Admin Offices    674.28
# 1              Accountant I    MA   M   Admin Offices    674.28
# 2              Accountant I    MA   M   Admin Offices    674.28
# 3  Administrative Assistant    MA    F  Admin Offices  47822.00
# 4                       NaN    MA    F  Admin Offices       NaN
# 5  Administrative Assistant    MA    F  Admin Offices  32406.02
# 6        Area Sales Manager    VA    F          Sales       NaN
# 7        Area Sales Manager    VT    F          Sales  55912.50
# 8        Area Sales Manager    WA  NaN          Sales       NaN
# 9        Area Sales Manager    NH   M           Sales  33773.70

# %%
# Filter rows based on a condition
filter_rows = df[(df.Salaries >1000) & (df.Salaries <5000)]
#it will display in bool
filter_rows.head()
#now it will display actual data
# Out:
#                     Position State  Sex MaritalDesc          CitizenDesc  \
# 37               BI Director    MA   M      Married           US Citizen
# 59                       NaN    MA   M       Single           US Citizen
# 102  Production Technician I    MA   M      Married  Eligible NonCitizen
# 119  Production Technician I    MA  NaN     Married           US Citizen
# 124                      NaN    MA    F      Single           US Citizen
#
#            EmploymentStatus         Department  Salaries   age   Race
# 37                      NaN              IT/IS   4160.00  23.0  White
# 59                   Active              IT/IS   2143.58   NaN  White
# 102  Voluntarily Terminated  Production          2977.50  28.0  White
# 119  Voluntarily Terminated  Production          1863.90  26.0  White
# 124                  Active  Production          2744.66  51.0  White
