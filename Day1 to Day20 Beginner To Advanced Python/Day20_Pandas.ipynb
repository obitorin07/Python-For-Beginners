# %%
import csv

# Sample student data
students = [
    {"StudentID": 1, "Name": "Alice", "Age": 20, "Grade": "A"},
    {"StudentID": 2, "Name": "Bob", "Age": 21, "Grade": "B"},
    {"StudentID": 3, "Name": "Charlie", "Age": 19, "Grade": "C"},
    {"StudentID": 4, "Name": "David", "Age": 22, "Grade": "B"},
    {"StudentID": 5, "Name": "Eve", "Age": 20, "Grade": "A"},
]

# Define the CSV file path
csv_file = "students.csv"

# Write student data to CSV file
with open(csv_file, mode='w', newline='') as file:
    fieldnames = ["StudentID", "Name", "Age", "Grade"]
    writer = csv.DictWriter(file, fieldnames=fieldnames)

    # Write header
    writer.writeheader()

    # Write student data
    for student in students:
        writer.writerow(student)

print(f"CSV file '{csv_file}' created successfully.")
# Out:
# CSV file 'students.csv' created successfully.

# %%
print(students)

# %% [markdown]
# ##education csv file

# %%
Name,Age,Marks,Subjects,Place
Alice,20,85,Math,New York
Bob,21,78,Science,Los Angeles
Charlie,19,92,English,Chicago
David,22,81,History,San Francisco
Eve,20,89,Geography,Houston
Frank,23,75,Math,Seattle
Grace,21,87,Science,Boston
Henry,20,83,English,Miami
Ivy,22,90,History,Atlanta
Jack,19,79,Geography,Dallas
Kelly,24,82,Math,Denver
Liam,20,88,Science,Phoenix
Mia,21,77,English,Philadelphia
Noah,22,91,History,Detroit
Olivia,19,84,Geography,Minneapolis
Peter,23,86,Math,San Diego
Quinn,21,80,Science,Portland
Rachel,20,92,English,Saint Louis
Sam,22,75,History,Tampa
Tina,24,89,Geography,Charlotte
Ursula,19,83,Math,Pittsburgh
Victor,23,87,Science,Indianapolis
Wendy,21,91,English,Orlando
Xavier,20,78,History,Raleigh
Yara,22,85,Geography,Washington D.C.
Zack,24,82,Math,New Orleans
Amy,19,88,Science,Las Vegas
Ben,23,76,English,San Antonio
Cathy,21,90,History,Kansas City
Daniel,20,84,Geography,Sacramento

# %%
import pandas as pd

df = pd.read_csv("/content/education.csv")
print(type(df))
print(df)
df.shape # print 1st one is row second one is column

# %%
df.head(10) #top 10 data
# Out:
#       Name  Age  Marks   Subjects          Place
# 0    Alice   20     85       Math       New York
# 1      Bob   21     78    Science    Los Angeles
# 2  Charlie   19     92    English        Chicago
# 3    David   22     81    History  San Francisco
# 4      Eve   20     89  Geography        Houston
# 5    Frank   23     75       Math        Seattle
# 6    Grace   21     87    Science         Boston
# 7    Henry   20     83    English          Miami
# 8      Ivy   22     90    History        Atlanta
# 9     Jack   19     79  Geography         Dallas

# %%
df.tail() #last 5 data default
# Out:
#       Name  Age  Marks   Subjects        Place
# 25    Zack   24     82       Math  New Orleans
# 26     Amy   19     88    Science    Las Vegas
# 27     Ben   23     76    English  San Antonio
# 28   Cathy   21     90    History  Kansas City
# 29  Daniel   20     84  Geography   Sacramento

# %%
df.tail(10) #default
# Out:
#       Name  Age  Marks   Subjects            Place
# 20  Ursula   19     83       Math       Pittsburgh
# 21  Victor   23     87    Science     Indianapolis
# 22   Wendy   21     91    English          Orlando
# 23  Xavier   20     78    History          Raleigh
# 24    Yara   22     85  Geography  Washington D.C.
# 25    Zack   24     82       Math      New Orleans
# 26     Amy   19     88    Science        Las Vegas
# 27     Ben   23     76    English      San Antonio
# 28   Cathy   21     90    History      Kansas City
# 29  Daniel   20     84  Geography       Sacramento

# %%
df.info() #display about data type also about storage use
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      30 non-null     object
#  1   Age       30 non-null     int64
#  2   Marks     30 non-null     int64
#  3   Subjects  30 non-null     object
#  4   Place     30 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.3+ KB

# %%
df.iloc[1] #1st index row data
# Out:
# Name                Bob
# Age                  21
# Marks                78
# Subjects        Science
# Place       Los Angeles
# Name: 1, dtype: object

# %%
df.Subjects.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          Math
# 1       Science
# 2       English
# 3       History
# 4     Geography
# 5          Math
# 6       Science
# 7       English
# 8       History
# 9     Geography
# 10         Math
# 11      Science
# 12      English
# 13      History
# 14    Geography
# 15         Math
# 16      Science
# 17      English
# 18      History
# 19    Geography
# 20         Math
# 21      Science
# 22      English
# 23      History
# 24    Geography
# 25         Math
# 26      Science
# 27      English
# 28      History
# 29    Geography
# Name: Subjects, dtype: object>

# %%
df.describe() # return statistical values
# Out:
#              Age      Marks
# count  30.000000  30.000000
# mean   21.166667  84.233333
# std     1.599210   5.282915
# min    19.000000  75.000000
# 25%    20.000000  80.250000
# 50%    21.000000  84.500000
# 75%    22.000000  88.750000
# max    24.000000  92.000000

# %%
help(pd)

# %%
x1 = [1,2,3,4,5]
x2 = [3,4,5,6,7]
x3 = list(range(1,25,5))

df = pd.DataFrame(columns=['x1','x2','x3'])

#result = pd.DataFrame(columns=['1st','2nd','3rd'])

# %%
df['x1']=  x1
df['x2'] = x2
df['x3'] = x3

# %%
df
# Out:
#    x1  x2  x3
# 0   1   3   1
# 1   2   4   6
# 2   3   5  11
# 3   4   6  16
# 4   5   7  21

# %%
df[df.x1>3] # it shows data only >3 from x1 column
# Out:
#    x1  x2  x3
# 3   4   6  16
# 4   5   7  21

# %% [markdown]
# ##creating new column

# %%
df['x4'] =[10,20,30,40,50]

# %%
df
# Out:
#    x1  x2  x3  x4
# 0   1   3   1  10
# 1   2   4   6  20
# 2   3   5  11  30
# 3   4   6  16  40
# 4   5   7  21  50

# %%
df.x4.isin([10,20,40]) # it returns bool values
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# Name: x4, dtype: bool

# %%
df[df.x4.isin([10,20])] # it will return 10 and 20
# Out:
#    x1  x2  x3  x4
# 0   1   3   1  10
# 1   2   4   6  20

# %% [markdown]
# ##update value specific position

# %%
df.iat[2,3] =25 #iat means index at [2,3] means second index row 3rd colum

# %%
df
# Out:
#    x1  x2  x3  x4
# 0   1   3   1  10
# 1   2   4   6  20
# 2   3   5  11  25
# 3   4   6  16  40
# 4   5   7  21  50

# %%
df.x1[2],df.x2[2] =None,None # it will add none is these 2 rows
# Out:
# <ipython-input-55-30ca23744af0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.x1[2],df.x2[2] =None,None # it will add none is these 2 rows
# <ipython-input-55-30ca23744af0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.x1[2],df.x2[2] =None,None # it will add none is these 2 rows

# %%
df
# Out:
#     x1   x2  x3  x4
# 0  1.0  3.0   1  10
# 1  2.0  4.0   6  20
# 2  NaN  NaN  11  25
# 3  4.0  6.0  16  40
# 4  5.0  7.0  21  50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      4 non-null      float64
#  1   x2      4 non-null      float64
#  2   x3      5 non-null      int64
#  3   x4      5 non-null      int64
# dtypes: float64(2), int64(2)
# memory usage: 288.0 bytes

# %%
df.describe()
# Out:
#              x1        x2         x3         x4
# count  4.000000  4.000000   5.000000   5.000000
# mean   3.000000  5.000000  11.000000  29.000000
# std    1.825742  1.825742   7.905694  15.968719
# min    1.000000  3.000000   1.000000  10.000000
# 25%    1.750000  3.750000   6.000000  20.000000
# 50%    3.000000  5.000000  11.000000  25.000000
# 75%    4.250000  6.250000  16.000000  40.000000
# max    5.000000  7.000000  21.000000  50.000000

# %%
df.isnull() # return bool
# Out:
#       x1     x2     x3     x4
# 0  False  False  False  False
# 1  False  False  False  False
# 2   True   True  False  False
# 3  False  False  False  False
# 4  False  False  False  False
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('x1').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
df.dropna(inplace =False) #it remove null value from entire row
# Out:
#     x1   x2  x3  x4
# 0  1.0  3.0   1  10
# 1  2.0  4.0   6  20
# 3  4.0  6.0  16  40
# 4  5.0  7.0  21  50

# %%
df.dropna(inplace =True) # it will remove row from directly from dataset for permenantly

# %%
df
# Out:
#     x1   x2  x3  x4
# 0  1.0  3.0   1  10
# 1  2.0  4.0   6  20
# 3  4.0  6.0  16  40
# 4  5.0  7.0  21  50

# %% [markdown]
# #filling values in empty cell

# %%
x1 = [1,2,3,4,5]
x2 = [3,4,5,6,7]
x3 = list(range(1,25,5))

df = pd.DataFrame(columns=['x1','x2','x3'])

#result = pd.DataFrame(columns=['1st','2nd','3rd'])

# %%
df['x1']=  x1
df['x2'] = x2
df['x3'] = x3

# %%
df['x4'] =[10,20,30,40,50]

# %%
df.x1[2],df.x2[2] =None,None
# Out:
# <ipython-input-80-340303aff98f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.x1[2],df.x2[2] =None,None
# <ipython-input-80-340303aff98f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.x1[2],df.x2[2] =None,None

# %%
df
# Out:
#     x1   x2  x3  x4
# 0  1.0  3.0   1  10
# 1  2.0  4.0   6  20
# 2  NaN  NaN  11  30
# 3  4.0  6.0  16  40
# 4  5.0  7.0  21  50

# %%
#adding value in missing cell

df.fillna(value = 250,inplace =False) #temporary
# Out:
#       x1     x2  x3  x4
# 0    1.0    3.0   1  10
# 1    2.0    4.0   6  20
# 2  250.0  250.0  11  30
# 3    4.0    6.0  16  40
# 4    5.0    7.0  21  50

# %%
#adding value in missing cell

df.fillna(value = 250,inplace =True) #Permanent

# %%
df
# Out:
#       x1     x2  x3  x4
# 0    1.0    3.0   1  10
# 1    2.0    4.0   6  20
# 2  250.0  250.0  11  30
# 3    4.0    6.0  16  40
# 4    5.0    7.0  21  50

# %%
df
# Out:
#     x1   x2  x3  x4
# 0  1.0  3.0   1  10
# 1  2.0  4.0   6  20
# 2  NaN  NaN  11  30
# 3  4.0  6.0  16  40
# 4  5.0  7.0  21  50

# %%
df.loc[:,['x1']].fillna(value =100,inplace = False) #take x1 column all rows :
# Out:
#       x1
# 0    1.0
# 1    2.0
# 2  100.0
# 3    4.0
# 4    5.0

# %%
df.loc[:,['x1','x2']].fillna(value =100,inplace = False)# take all x1 and x2 column rows
# Out:
#       x1     x2
# 0    1.0    3.0
# 1    2.0    4.0
# 2  100.0  100.0
# 3    4.0    6.0
# 4    5.0    7.0

# %%
df
# Out:
#     x1   x2  x3  x4
# 0  1.0  3.0   1  10
# 1  2.0  4.0   6  20
# 2  NaN  NaN  11  30
# 3  4.0  6.0  16  40
# 4  5.0  7.0  21  50

# %% [markdown]
# #Operations in Pandas And Numpy

# %%
import pandas as pd
import numpy as np

# %%
c1 = [10,20,30,40,50]
c2 = [50,60,70,80,90]

c3 = list(range(5,30,5))

df = pd.DataFrame({"Column1":c1,"Column2":c2,"Column3":c3})

# %%
df
# Out:
#    Column1  Column2  Column3
# 0       10       50        5
# 1       20       60       10
# 2       30       70       15
# 3       40       80       20
# 4       50       90       25

# %%
df.Column1 + df.Column2
# Out:
# 0     60
# 1     80
# 2    100
# 3    120
# 4    140
# dtype: int64

# %%
df
# Out:
#    Column1  Column2  Column3
# 0       10       50        5
# 1       20       60       10
# 2       30       70       15
# 3       40       80       20
# 4       50       90       25

# %%
df
# Out:
#    Column1  Column2  Column3
# 0       10       50        5
# 1       20       60       10
# 2       30       70       15
# 3       40       80       20
# 4       50       90       25

# %%
df['Column4'] = df.Column1 + df.Column2 * df.Column3 # storing value in new column using PEMDAS RUle

# %%
df
# Out:
#    Column1  Column2  Column3  Column4
# 0       10       50        5      260
# 1       20       60       10      620
# 2       30       70       15     1080
# 3       40       80       20     1640
# 4       50       90       25     2300

# %% [markdown]
# ##Operation sum mean

# %%
df.Column1.mean()
# Out:
# 30.0

# %%
df.Column2.mean()
# Out:
# 70.0

# %%
df.Column1.sum()
# Out:
# 150

# %%
df.Column1.max()
# Out:
# 50

# %%
df.Column1.min()
# Out:
# 10

# %%
df.Column1.count()
# Out:
# 5

# %%
df.dtypes
# Out:
# Column1    int64
# Column2    int64
# Column3    int64
# Column4    int64
# dtype: object

# %% [markdown]
# #Using lambda in Pandas

# %%
print(df)
df.apply(lambda x : x.max()+x.min()) # it add min and max value from each column
# Out:
#    Column1  Column2  Column3  Column4
# 0       10       50        5      260
# 1       20       60       10      620
# 2       30       70       15     1080
# 3       40       80       20     1640
# 4       50       90       25     2300
# Column1      60
# Column2     140
# Column3      30
# Column4    2560
# dtype: int64

# %%
df
# Out:
#    Column1  Column2  Column3  Column4
# 0       10       50        5      260
# 1       20       60       10      620
# 2       30       70       15     1080
# 3       40       80       20     1640
# 4       50       90       25     2300

# %%
print(df)
df.Column1.apply(lambda x: x**2)
# Out:
#    Column1  Column2  Column3  Column4
# 0       10       50        5      260
# 1       20       60       10      620
# 2       30       70       15     1080
# 3       40       80       20     1640
# 4       50       90       25     2300
# 0     100
# 1     400
# 2     900
# 3    1600
# 4    2500
# Name: Column1, dtype: int64

# %%
print(df)
df.apply(lambda x: x.max()+x.min(), axis = 1) # axis is reffering to row 1
# Out:
#    Column1  Column2  Column3  Column4
# 0       10       50        5      260
# 1       20       60       10      620
# 2       30       70       15     1080
# 3       40       80       20     1640
# 4       50       90       25     2300
# 0     265
# 1     630
# 2    1095
# 3    1660
# 4    2325
# dtype: int64

# %%
print(df)
df.apply(lambda x: x.max()+x.min(), axis = 0) # axis is reffering to 1 columns
# Out:
#    Column1  Column2  Column3  Column4
# 0       10       50        5      260
# 1       20       60       10      620
# 2       30       70       15     1080
# 3       40       80       20     1640
# 4       50       90       25     2300
# Column1      60
# Column2     140
# Column3      30
# Column4    2560
# dtype: int64

# %%
df.Column1.apply(lambda x : x+10)
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# 4    60
# Name: Column1, dtype: int64

# %%
def manipulate(x):
  if x>25:
    return "yes"
  else:
    return 'No'

# %%
df.Column1.apply(lambda x : manipulate(x))
# Out:
# 0     No
# 1     No
# 2    yes
# 3    yes
# 4    yes
# Name: Column1, dtype: object

# %%
df.Column1.apply(manipulate)
# Out:
# 0     No
# 1     No
# 2    yes
# 3    yes
# 4    yes
# Name: Column1, dtype: object
